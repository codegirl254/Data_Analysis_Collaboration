# %%
import pandas as pd

# %%
df=pd.read_csv('DataFiles/census.csv')

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.tail()
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.values
# Out:
# array([[90, '?', 77053, ..., 40, 'United-States', '<=50K'],
#        [82, 'Private', 132870, ..., 18, 'United-States', '<=50K'],
#        [66, '?', 186061, ..., 40, 'United-States', '<=50K'],
#        ...,
#        [40, 'Private', 154374, ..., 40, 'United-States', '>50K'],
#        [58, 'Private', 151910, ..., 40, 'United-States', '<=50K'],
#        [22, 'Private', 201490, ..., 20, 'United-States', '<=50K']],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 8453    25           Private  308144     Bachelors             13
# 8645    90           Private   52386  Some-college             10
# 12202   21           Private  250051  Some-college             10
# 14346   20           Private  107658  Some-college             10
# 15603   25           Private  195994       1st-4th              2
# 17344   21           Private  243368     Preschool              1
# 19067   46           Private  173243       HS-grad              9
# 20388   30           Private  144593       HS-grad              9
# 20507   19           Private   97261       HS-grad              9
# 22783   19           Private  138153  Some-college             10
# 22934   19           Private  146679  Some-college             10
# 23276   49           Private   31267       7th-8th              4
# 23660   25           Private  195994       1st-4th              2
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
children=df[df['age']<18]
children
# childrenUpdated=df['fnlwgt'].sum()
# childrenUpdated
# Out:
#        age workclass  fnlwgt education  education.num marital.status  \
# 1092    17   Private  148522      11th              7  Never-married
# 1093    17   Private   93235      12th              8  Never-married
# 1116    17   Private  184924       9th              5  Never-married
# 1118    17   Private  116626      11th              7  Never-married
# 1235    17   Private  209949      11th              7  Never-married
# ...    ...       ...     ...       ...            ...            ...
# 31869   17         ?  256173      10th              6  Never-married
# 31948   17   Private  214787      12th              8  Never-married
# 32035   17   Private   24090   HS-grad              9  Never-married
# 32310   17   Private  311907      11th              7  Never-married
# 32457   17   Private  117798      10th              6  Never-married
#
#               occupation relationship   race     sex  capital.gain  \
# 1092       Other-service    Own-child  White    Male             0
# ...

# %%
childrenUpdated=children['fnlwgt'].sum()
childrenUpdated
# Out:
# 73360282

# %%
youth=df[(df['age']>=18) & (df['age'] <=35)]
youth
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 5       34   Private  216864       HS-grad              9            Divorced
# 13      32   Private  136204       Masters             14           Separated
# 18      22   Private  119592    Assoc-acdm             12       Never-married
# 19      34   Private  203034     Bachelors             13           Separated
# 21      29   Private   77009          11th              7           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32552   32   Private   34066          10th              6  Married-civ-spouse
# 32554   32   Private  116138       Masters             14       Never-married
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
middleAge=df[(df['age']>=36) & (df['age'] <=55)]
middleAge
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 6       38           Private  150601          10th              6
# 9       41           Private   70037  Some-college             10
# 10      45           Private  172274     Doctorate             16
# ...    ...               ...     ...           ...            ...
# 32550   43         State-gov  255835  Some-college             10
# 32551   43  Self-emp-not-inc   27242  Some-college             10
# 32553   43           Private   84661     Assoc-voc             11
# 32555   53           Private  321865       Masters             14
# 32558   40           Private  154374       HS-grad              9
#
#            marital.status         occupation    relationship   race     sex  \
# 3                Divorced  Machine-op-inspct       Unmarried  White  Female
# ...

# %%
old=df[(df['age']>=56) & (df['age'] <=69)]
old
# Out:
#        age    workclass  fnlwgt     education  education.num  \
# 2       66            ?  186061  Some-college             10
# 8       68  Federal-gov  422013       HS-grad              9
# 17      57      Private  317847       Masters             14
# 22      61      Private   29059       HS-grad              9
# 24      61            ?  135285       HS-grad              9
# ...    ...          ...     ...           ...            ...
# 32495   61      Private  355645       HS-grad              9
# 32496   60            ?  134152           9th              5
# 32504   57      Private  153918       HS-grad              9
# 32525   58      Private  147707          11th              7
# 32559   58      Private  151910       HS-grad              9
#
#            marital.status        occupation   relationship   race     sex  \
# 2                 Widowed                 ?      Unmarried  Black  Female
# 8                Divorced    Prof-specialty  Not-in-family  White  Female
# ...

# %%
veryOld=df[df['age']>=70]
veryOld
# Out:
#        age  workclass  fnlwgt  education  education.num      marital.status  \
# 0       90          ?   77053    HS-grad              9             Widowed
# 1       82    Private  132870    HS-grad              9             Widowed
# 7       74  State-gov   88638  Doctorate             16       Never-married
# 44      71          ?  100820    HS-grad              9  Married-civ-spouse
# 46      71    Private  110380    HS-grad              9  Married-civ-spouse
# ...    ...        ...     ...        ...            ...                 ...
# 32500   82          ?  403910    HS-grad              9       Never-married
# 32506   71    Private  138145        9th              5  Married-civ-spouse
# 32528   81          ?  120478  Assoc-voc             11            Divorced
# 32541   71          ?  287372  Doctorate             16  Married-civ-spouse
# 32544   72          ?  129912    HS-grad              9  Married-civ-spouse
#
# ...

# %%
## check on consistency btn education level and education number
